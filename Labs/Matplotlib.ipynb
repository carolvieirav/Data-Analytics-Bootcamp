# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
plt.plot(x,y, color='purple');
plt.plot(x,z, color= 'pink');

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
fig, ax = plt.subplots(1, 2)

ax[0].plot(x, y);
ax[1].plot(x, z);

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here

x = np.arange(0,100)
y = x*2
z = -x

fig,(ax1,ax2) = plt.subplots(nrows=1,ncols=2,figsize=(10,5));

ax1.plot(x,y,color='purple',label = 'Corona Vairus');
ax1.set_title('Caos Social',fontsize=16);
ax1.legend();

ax2.plot(x,z,color='pink',label = 'Iron Beer');
ax2.set_title('Diversão da Ironhack',fontsize=16);
ax2.legend();

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
# your code here
x = np.arange(0,100)
y = x**2
z = np.exp(x)

fig,(ax1,ax2) = plt.subplots(nrows=1,ncols=2,figsize=(16,8))

ax1.plot(x,y,c='purple');
ax1.set_title('y = $x^2$',fontsize=16);
ax1.set_xlabel('x',fontsize=16);
ax1.set_ylabel('y',fontsize=16);

ax2.plot(x,z,c='pink');
ax2.set_yscale('log');
ax2.set_title('y = e$^x$',fontsize=16);
ax2.set_xlabel('x',fontsize=16);
ax2.set_ylabel('log(y)',fontsize=16);

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
# your code here
x = np.arange(0,100)
y = x**2
z = np.exp(x)

fig,(ax1,ax2) = plt.subplots(nrows=1,ncols=2,figsize=(16,8))

ax1.plot(x,y,color='pink',label='y = $x^2$')
ax1.set_title('coquinha de seiscentas',fontsize=32)
ax1.set_xlabel('x',fontsize=32)
ax1.set_ylabel('y',fontsize=32)
ax1.legend(fontsize=32)

ax2.plot(x,z,color='purple',label='y = e$^x$')
ax2.set_yscale('log')
ax2.set_title('hula hula é 1 real',fontsize=32)
ax2.set_xlabel('x',fontsize=32)
ax2.set_ylabel('log(y)',fontsize=32)
ax2.legend(fontsize=32)

plt.show()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`.
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit = pd.read_csv('../Fitbit2.csv')

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here

monthly_steps = fitbit.groupby(by='Months',sort=False).median().loc[:,['Steps']].reset_index()
data = fitbit.groupby(by=['Work_or_Weekend','Months'],sort=False).median().loc[:,'Steps']
week_data = data[1].reset_index()
weekend_data = data[0].reset_index()

# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here
fig,(ax1,ax2) = plt.subplots(nrows=1,ncols=2,figsize=(12,4))

ax1.plot(monthly_steps.iloc[:,0],monthly_steps.iloc[:,1],c='pink')
ax1.set_title('Monthly steps',fontsize=14)
ax1.set_xlabel('months',fontsize=16)
ax1.set_ylabel('Steps (median)',fontsize=14)

ax2.plot(week_data.iloc[:,0],week_data.iloc[:,1],c='purple',label='During Week')
ax2.plot(weekend_data.iloc[:,0],weekend_data.iloc[:,1],color='pink',label='During Weekend')
ax2.set_title('Week vs. Weekend Steps',fontsize=14)
ax2.set_xlabel('months',fontsize=16)
ax2.set_ylabel('Steps (median)',fontsize=14)
ax2.legend(fontsize=14)


plt.sca(ax1)
plt.xticks(rotation=45)

plt.sca(ax2)
plt.xticks(rotation=45)
plt.show()


fig.savefig('figures.png')

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
# your code here
lightly_active =  fitbit.loc[:,['Steps','Minutes Lightly Active']]
fairly_active =  fitbit.loc[:,['Steps','Minutes Fairly Active']]
very_active =  fitbit.loc[:,['Steps','Minutes Very Active']]

fig,(ax1,ax2,ax3) = plt.subplots(nrows=1,ncols=3,figsize=(16,8))
tpl = (ax1,ax2,ax3)
i = 0

for data in [lightly_active,fairly_active,very_active]:
    tpl[i].scatter(data.iloc[:,0],data.iloc[:,1])
    i+=1
    

plt.legend(['Minutes Lightly Active', 'Minutes Fairly Active','Minutes Very Active'])
plt.xlabel('minutes')
plt.ylabel('Steps')

plt.show()

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`.
# * db: `titanic`
# * table: `titanic`

# %%
# your code here

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
# your code here

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here

# %%
# CATEGORICAL VARIABLES
# your code here

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
"""
your comments here
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# your code here

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

# %%
# Method 2 - seaborn
# your code here

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# your code here

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# %%
"""
your comments here
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
your comments here
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here

# %%
# Method 2 - seaborn
# your code here

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
# your code here

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
your comments here
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
# your code here

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
# your code here
